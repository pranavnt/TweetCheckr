# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns

sns.set()

# %%
dataset = pd.read_excel('dataset.xlsx')

# %%
dataset
# Out:
#      Rank  Influence \nScore Date of Max \nInfluence  \
# 0       1               31.0              2020-02-04
# 1       2               31.0              2020-02-04
# 2       3               31.0              2020-02-04
# 3       4               31.0              2020-02-04
# 4       5               31.0              2020-02-04
# ..    ...                ...                     ...
# 761   762                NaN                     NaT
# 762   763                NaN                     NaT
# 763   764                NaN                     NaT
# 764   765                NaN                     NaT
# 765   766                NaN                     NaT
#
#                                          Summary Tweet
# 0    "RT @NPR: One doctor in Hong Kong says he unde...
# 1    "RT @NPR: One doctor in Hong Kong says he unde...
# 2    RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# 3    RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# ...

# %%
dataset = dataset.drop(['Date of Max \nInfluence','Rank'],axis=1).dropna()

# %%
dataset
# Out:
#      Influence \nScore                                      Summary Tweet
# 0                 31.0  "RT @NPR: One doctor in Hong Kong says he unde...
# 1                 31.0  "RT @NPR: One doctor in Hong Kong says he unde...
# 2                 31.0  RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# 3                 31.0  RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# 4                 31.0  RT @Independent: Hong Kong hospital workers st...
# ..                 ...                                                ...
# 221                6.0  RT @NomenChanX: @ReutersWorld Amazon se retira...
# 222                6.0  RT @raythemouse: Does this image show scale of...
# 223                6.0  RT @ReutersBiz: Amazon withdraws from Barcelon...
# 224                6.0  RT @siva217: Watch @AgendaFreeTV's broadcast: ...
# 225                6.0  RT @willian18410696: @NicolasMaduro @ConCiliaF...
#
# [226 rows x 2 columns]

# %%
dataset['Influence \nScore'].hist()

# %%
dataset['Influence \nScore'] = dataset['Influence \nScore']>20

# %%
dataset
# Out:
#      Influence \nScore                                      Summary Tweet
# 0                 True  "RT @NPR: One doctor in Hong Kong says he unde...
# 1                 True  "RT @NPR: One doctor in Hong Kong says he unde...
# 2                 True  RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# 3                 True  RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# 4                 True  RT @Independent: Hong Kong hospital workers st...
# ..                 ...                                                ...
# 221              False  RT @NomenChanX: @ReutersWorld Amazon se retira...
# 222              False  RT @raythemouse: Does this image show scale of...
# 223              False  RT @ReutersBiz: Amazon withdraws from Barcelon...
# 224              False  RT @siva217: Watch @AgendaFreeTV's broadcast: ...
# 225              False  RT @willian18410696: @NicolasMaduro @ConCiliaF...
#
# [226 rows x 2 columns]

# %%
encode_bool = lambda x: 1 if x==True else 0

# %%
dataset['Influence \nScore'] = [encode_bool(i) for i in dataset['Influence \nScore']]

# %%
dataset
# Out:
#      Influence \nScore                                      Summary Tweet
# 0                    1  "RT @NPR: One doctor in Hong Kong says he unde...
# 1                    1  "RT @NPR: One doctor in Hong Kong says he unde...
# 2                    1  RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# 3                    1  RT @ABCWorldNews: Hundreds of Hong Kong hospit...
# 4                    1  RT @Independent: Hong Kong hospital workers st...
# ..                 ...                                                ...
# 221                  0  RT @NomenChanX: @ReutersWorld Amazon se retira...
# 222                  0  RT @raythemouse: Does this image show scale of...
# 223                  0  RT @ReutersBiz: Amazon withdraws from Barcelon...
# 224                  0  RT @siva217: Watch @AgendaFreeTV's broadcast: ...
# 225                  0  RT @willian18410696: @NicolasMaduro @ConCiliaF...
#
# [226 rows x 2 columns]
